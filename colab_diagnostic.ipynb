# %% [markdown]
# # AI Education Platform — Colab Diagnostic
#
# Original project is cloned from GitHub. No source modification.

# %%
# !rm -rf /content/ai-edu-platform
# !git clone --depth 1 https://github.com/hijaz7861/ai-edu-platform.git /content/ai-edu-platform
# %cd /content/ai-edu-platform

# %%
# !apt-get update -qq
# !apt-get install -y -qq tesseract-ocr

# %%
# !python -m pip install -r requirements.txt
# !python -m pip install pytest

# %%
# !pytest -q

# %%
from app import app
print('FLASK_APP_IMPORT=OK')
print('AI EDUCATION PLATFORM COLAB DIAGNOSTIC COMPLETE')
